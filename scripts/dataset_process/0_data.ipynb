# %% [markdown]
# **MOBILITAPP DATASET**

# %%
import sys  
sys.path.insert(0, '../../src/')
import matplotlib.pyplot as plt

import dataset as dt
import numpy as np


WINDOW_SIZE = 200
OVERLAP_FACTOR = 0.5
MIN_SAMPLES = 0
OBFUSCATION_FACTOR = 0.0
UNDERSAMPLING_LIMIT = 20000

# %% [markdown]
# READ RAW DATA

# %%
# 5 min
dataset = dt.Dataset('ours', WINDOW_SIZE, OVERLAP_FACTOR)
dataset.read_raw_data()
# Out:
# Reading raw data files...
# 100%|██████████| 9709/9709 [04:22<00:00, 36.93it/s]
# Succesfully data preprocessing.

# %% [markdown]
# TRAIN, VALIDATION, TEST SPLIT

# %%
dataset.smart_split_sets()
# Out:
# ######### Bike #########
#      - Total samples: 4057
#      - Train samples: 2839
#      - Test samples: 1217
#      - Train dist: {'18caffff8f9e983b': 104, '8d89eabbfbd6a2ea': 46, 'ade9cca025b30c45': 2281, '224f5d897e62afbb': 44, '84618f237d30bf44': 96, 'd6d193d3f7477465': 151, '4ec91e68023af0de': 40, '2ab87c9ee8de9eb7': 1295}
#      - Test dist: {}
#      - Mid train samp: 4057
#      - Mid test samp: 0
#      - Still needed test samples: 1217
# ######### Bus #########
#      - Total samples: 35859
#      - Train samples: 25101
#      - Test samples: 10757
#      - Train dist: {'2413fb9f8a2011ae': 326, 'ef210a45857f6cba': 81, 'b34815c4c2784c19': 26, '198242fb4b0b1987': 2044, '2b09ad0e2fc19550': 1472, '444f1148381db72e': 3661, 'e2f173433854980a': 1137, 'f95c6ddbef2a95ab': 19282, '7a988e5141dfdbbd': 81}
# ...

# %%
dataset.plot_class_distribution(title='Dataset Distribution 14th December 2023')

# %% [markdown]
# SAVE STATE
#
# This could last some minutes.

# %%
dataset.save_data()
# Out:
# ../data/Window200Overlap0.5/labels.txt - saved succesfully
# ../data/Window200Overlap0.5/users.txt - saved succesfully
# ../data/Window200Overlap0.5/train.txt - saved succesfully
# ../data/Window200Overlap0.5/val.txt - saved succesfully
# ../data/Window200Overlap0.5/test.txt - saved succesfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dataset.save_data()
#
# File c:\Users\miquel\Desktop\TFG\BASE\scripts\../src\dataset.py:181, in Dataset.save_data(self, extra_name)
#     179 # Flatten the 3D array to 2D
#     180 flattened_sensors = self.sensor_data.reshape(-1, self.sensor_data.shape[-1])
# --> 181 np.savetxt(data_name+'sensors'+str(shape)+'.txt' ,flattened_sensors, fmt='%s')
#     182 print(data_name+'sensors'+str(shape)+'.txt - saved succesfully')
#
# File <__array_function__ internals>:180, in savetxt(*args, **kwargs)
#
# ...
